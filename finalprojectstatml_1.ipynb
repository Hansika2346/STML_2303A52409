# %% [markdown]
# <a href="https://colab.research.google.com/github/Hansika2346/STML_2303A52409/blob/main/finalprojectstatml_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
d=pd.read_csv('/content/tourism_dataset.csv')
print(d)
# Out:
#         Location Country    Category  Visitors  Rating    Revenue  \
# 0     kuBZRkVsAR   India      Nature    948853    1.32   84388.38
# 1     aHKUXhjzTo     USA  Historical    813627    2.01  802625.60
# 2     dlrdYtJFTA  Brazil      Nature    508673    1.42  338777.11
# 3     DxmlzdGkHK  Brazil  Historical    623329    1.09  295183.60
# 4     WJCCQlepnz  France    Cultural    124867    1.43  547893.24
# ...          ...     ...         ...       ...     ...        ...
# 5984  xAzwnVKAqz     USA       Urban    828137    1.97  132848.78
# 5985  IfKotyaJFC  France      Nature    276317    3.53  325183.96
# 5986  bPyubCWGgA   Egypt       Beach    809198    3.37  927336.50
# 5987  kkWIucpBnu   Egypt    Cultural    808303    2.52  115791.43
# 5988  gHXUrdticm  France    Cultural     40939    4.65  957026.85
#
#      Accommodation_Available
# 0                        Yes
# 1                         No
# 2                        Yes
# 3                        Yes
# ...

# %%
d.isnull().sum()
# Out:
# Location                   0
# Country                    0
# Category                   0
# Visitors                   0
# Rating                     0
# Revenue                    0
# Accommodation_Available    0
# dtype: int64

# %%
y=d['Accommodation_Available']
print(y)
# Out:
# 0       Yes
# 1        No
# 2       Yes
# 3       Yes
# 4        No
#        ...
# 5984     No
# 5985    Yes
# 5986     No
# 5987    Yes
# 5988    Yes
# Name: Accommodation_Available, Length: 5989, dtype: object

# %%
x=d.drop('Accommodation_Available',axis=1)
print(x)
# Out:
#         Location Country    Category  Visitors  Rating    Revenue
# 0     kuBZRkVsAR   India      Nature    948853    1.32   84388.38
# 1     aHKUXhjzTo     USA  Historical    813627    2.01  802625.60
# 2     dlrdYtJFTA  Brazil      Nature    508673    1.42  338777.11
# 3     DxmlzdGkHK  Brazil  Historical    623329    1.09  295183.60
# 4     WJCCQlepnz  France    Cultural    124867    1.43  547893.24
# ...          ...     ...         ...       ...     ...        ...
# 5984  xAzwnVKAqz     USA       Urban    828137    1.97  132848.78
# 5985  IfKotyaJFC  France      Nature    276317    3.53  325183.96
# 5986  bPyubCWGgA   Egypt       Beach    809198    3.37  927336.50
# 5987  kkWIucpBnu   Egypt    Cultural    808303    2.52  115791.43
# 5988  gHXUrdticm  France    Cultural     40939    4.65  957026.85
#
# [5989 rows x 6 columns]

# %%
x.dtypes
# Out:
# Location     object
# Country      object
# Category     object
# Visitors      int64
# Rating      float64
# Revenue     float64
# dtype: object

# %%
for column in x.columns:
    print(x[column].value_counts())
# Out:
# Location
# kuBZRkVsAR    1
# nhBhGoMHDe    1
# YspVRTPULE    1
# NxsobMMCiE    1
# NrkusOEBVk    1
#              ..
# amZohYzBPa    1
# STRyQjwLNi    1
# zMCXXQKwWH    1
# ythutjqKUZ    1
# gHXUrdticm    1
# Name: count, Length: 5989, dtype: int64
# Country
# Egypt        912
# India        896
# France       857
# USA          848
# Brazil       840
# Australia    830
# China        806
# Name: count, dtype: int64
# Category
# Adventure     1037
# Urban         1006
# Cultural       998
# Beach          998
# Historical     994
# Nature         956
# Name: count, dtype: int64
# Visitors
# 649167    2
# 590896    2
# 577353    2
# 733011    2
# 450785    2
#          ..
# 487014    1
# 583867    1
# 976128    1
# 274442    1
# 40939     1
# Name: count, Length: 5969, dtype: int64
# Rating
# 3.66    28
# 4.15    25
# 1.81    25
# 2.91    24
# 3.50    24
#         ..
# 4.08     7
# 2.33     7
# 1.66     7
# 4.99     6
# 4.59     5
# Name: count, Length: 401, dtype: int64
# Revenue
# ...

# %%
for column in x.columns:
    print(x[column].unique())
# Out:
# ['kuBZRkVsAR' 'aHKUXhjzTo' 'dlrdYtJFTA' ... 'bPyubCWGgA' 'kkWIucpBnu'
#  'gHXUrdticm']
# ['India' 'USA' 'Brazil' 'France' 'Egypt' 'China' 'Australia']
# ['Nature' 'Historical' 'Cultural' 'Beach' 'Adventure' 'Urban']
# [948853 813627 508673 ... 809198 808303  40939]
# [1.32 2.01 1.42 1.09 1.43 2.19 3.92 2.5  4.1  1.98 4.2  1.76 1.06 2.21
#  3.41 3.63 2.98 1.34 4.65 1.15 4.36 3.45 4.33 1.21 3.6  4.24 1.87 1.17
#  2.26 3.67 3.86 4.97 3.9  2.16 1.07 2.81 2.58 2.14 3.05 2.84 3.74 2.25
#  3.4  1.16 3.24 1.9  3.55 2.4  3.32 3.82 2.93 4.82 1.1  2.   4.3  3.78
#  1.01 1.4  4.89 1.5  1.96 4.73 4.96 4.16 1.91 3.75 2.77 4.44 1.   3.57
#  2.8  4.54 3.7  3.58 1.63 4.76 4.17 3.94 4.38 4.93 2.17 2.56 4.85 3.47
#  3.28 1.48 4.78 3.89 2.27 2.3  2.11 3.44 3.61 3.13 4.69 3.68 3.77 3.03
#  4.84 2.61 3.62 2.29 4.09 3.97 1.23 2.47 2.64 3.37 4.01 1.85 1.03 4.88
#  2.97 2.62 4.28 3.02 1.59 1.86 1.12 3.51 1.8  1.53 2.52 3.91 1.65 4.67
#  1.67 1.37 3.43 3.8  2.87 1.45 3.96 1.52 3.95 3.66 4.81 1.79 4.74 2.95
# ...

# %%
location_mapping = {location: i for i, location in enumerate(x['Location'].unique())}
country_mapping = {country: i for i, country in enumerate(x['Country'].unique())}
category_mapping = {category: i for i, category in enumerate(x['Category'].unique())}

x['Location'] = x['Location'].map(location_mapping)
x['Country'] = x['Country'].map(country_mapping)
x['Category'] = x['Category'].map(category_mapping)

# %%
x.dtypes
# Out:
# Location      int64
# Country       int64
# Category      int64
# Visitors      int64
# Rating      float64
# Revenue     float64
# dtype: object

# %%
x.head()
# Out:
#    Location  Country  Category  Visitors  Rating    Revenue
# 0         0        0         0    948853    1.32   84388.38
# 1         1        1         1    813627    2.01  802625.60
# 2         2        2         0    508673    1.42  338777.11
# 3         3        2         1    623329    1.09  295183.60
# 4         4        3         2    124867    1.43  547893.24

# %%
d.isnull().sum()
# Out:
# Location                   0
# Country                    0
# Category                   0
# Visitors                   0
# Rating                     0
# Revenue                    0
# Accommodation_Available    0
# dtype: int64

# %%
y.replace(['Yes', 'No'], [1, 0], inplace=True)
print(y)
# Out:
# 0       1
# 1       0
# 2       1
# 3       1
# 4       0
#        ..
# 5984    0
# 5985    1
# 5986    0
# 5987    1
# 5988    1
# Name: Accommodation_Available, Length: 5989, dtype: int64
# <ipython-input-14-18932f521dc7>:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   y.replace(['Yes', 'No'], [1, 0], inplace=True)

# %%
Y=d['Accommodation_Available']
print(Y)
# Out:
# 0       1
# 1       0
# 2       1
# 3       1
# 4       0
#        ..
# 5984    0
# 5985    1
# 5986    0
# 5987    1
# 5988    1
# Name: Accommodation_Available, Length: 5989, dtype: int64

# %% [markdown]
# SPLITING

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(x,y,test_size=0.2)

# %%
print(X_train)
# Out:
#       Location  Country  Category  Visitors  Rating    Revenue
# 4226      4226        0         4    291336    3.94   72053.01
# 5820      5820        3         3    552224    4.73  194681.20
# 5065      5065        6         0    638685    2.53  866348.94
# 3847      3847        4         2    733011    2.52  855989.88
# 4173      4173        0         4    294300    3.04  967744.90
# ...        ...      ...       ...       ...     ...        ...
# 1780      1780        1         5    151213    2.25  592179.54
# 4100      4100        0         4    539333    2.30  817889.16
# 5514      5514        2         5    951629    4.79  496396.35
# 1098      1098        2         4    507425    4.12  676253.53
# 5579      5579        5         3    989298    3.83  218890.03
#
# [4791 rows x 6 columns]

# %%
print(X_test)
# Out:
#       Location  Country  Category  Visitors  Rating    Revenue
# 3416      3416        5         1    794755    2.50   56493.73
# 3787      3787        4         2    283260    3.54  699951.37
# 1378      1378        1         4    831297    3.66   69836.09
# 409        409        5         5    378630    3.37  457782.54
# 3747      3747        6         2    228177    4.80  514042.54
# ...        ...      ...       ...       ...     ...        ...
# 2645      2645        5         3    384099    3.05  279666.74
# 4374      4374        2         2    682115    2.52  117414.86
# 3566      3566        1         1    979173    1.47  772756.25
# 3985      3985        6         0    948690    3.92  882867.66
# 5508      5508        3         3    316987    4.82  852327.23
#
# [1198 rows x 6 columns]

# %%
print(Y_train)
# Out:
# 4226    0
# 5820    1
# 5065    1
# 3847    0
# 4173    0
#        ..
# 1780    0
# 4100    0
# 5514    0
# 1098    1
# 5579    1
# Name: Accommodation_Available, Length: 4791, dtype: int64

# %%
print(Y_test)
# Out:
# 3416    1
# 3787    0
# 1378    0
# 409     0
# 3747    1
#        ..
# 2645    0
# 4374    0
# 3566    0
# 3985    0
# 5508    0
# Name: Accommodation_Available, Length: 1198, dtype: int64

# %%
y.value_counts()
# Out:
# Accommodation_Available
# 1    3013
# 0    2976
# Name: count, dtype: int64

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
from sklearn.linear_model import LogisticRegression
lr2=LogisticRegression(max_iter=1000)
lr2.fit(X_train,Y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
yp1=lr2.predict(X_test)
print(accuracy_score(Y_test,yp1))
# Out:
# 0.49081803005008345

# %%
print(confusion_matrix(Y_test,yp1))
# Out:
# [[375 203]
#  [407 213]]

# %%
print(classification_report(Y_test,yp1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.48      0.65      0.55       578
#            1       0.51      0.34      0.41       620
#
#     accuracy                           0.49      1198
#    macro avg       0.50      0.50      0.48      1198
# weighted avg       0.50      0.49      0.48      1198

# %%
##PERCEPTRON CLASSIFICATION
from sklearn.linear_model import Perceptron
lr1=Perceptron()
lr1.fit(X_train,Y_train)
# Out:
# Perceptron()

# %%
yp1=lr1.predict(X_test)
print(accuracy_score(Y_test,yp1))
# Out:
# 0.5217028380634391

# %%
print(confusion_matrix(Y_test,yp1))
# Out:
# [[148 430]
#  [143 477]]

# %%
print(classification_report(Y_test,yp1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.51      0.26      0.34       578
#            1       0.53      0.77      0.62       620
#
#     accuracy                           0.52      1198
#    macro avg       0.52      0.51      0.48      1198
# weighted avg       0.52      0.52      0.49      1198

# %%
##SVM CLASSIFICATION
from sklearn.svm import SVC
lr=SVC()
lr.fit(X_train,Y_train)
# Out:
# SVC()

# %%
yp=lr.predict(X_test)
print(accuracy_score(Y_test,yp))
# Out:
# 0.5091819699499165

# %%
print(confusion_matrix(Y_test,yp))
# Out:
# [[373 205]
#  [383 237]]

# %%
print(classification_report(Y_test,yp))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.49      0.65      0.56       578
#            1       0.54      0.38      0.45       620
#
#     accuracy                           0.51      1198
#    macro avg       0.51      0.51      0.50      1198
# weighted avg       0.52      0.51      0.50      1198

# %% [markdown]
# BEFORE PCA

# %% [markdown]
# FOR KNN

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %%
accuracy_list=[]
l=[]
for i in range(1,6):
  bkn=KNeighborsClassifier(n_neighbors=i)
  bkn.fit(X_train,Y_train)
  accuracy_list.append([bkn.score(X_test,Y_test)])
  l.append(i+1)

# %%
plt.plot(l,accuracy_list)

# %% [markdown]
# FOR SVM

# %%
import torch
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
print(f"Using device: {device}")
# Out:
# Using device: cpu

# %%
svc=SVC()
# Initialize the model
#svc.to(device)
svc.fit(X_train,Y_train)
# Out:
# SVC()

# %%
y_pred=svc.predict(X_test)
accuracy_svc=accuracy_score(Y_test,y_pred)

# %%
print(accuracy_svc)
# Out:
# 0.5091819699499165

# %%
c_report =classification_report(Y_test,y_pred)
print(c_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.49      0.65      0.56       578
#            1       0.54      0.38      0.45       620
#
#     accuracy                           0.51      1198
#    macro avg       0.51      0.51      0.50      1198
# weighted avg       0.52      0.51      0.50      1198

# %%
c_m=confusion_matrix(Y_test,y_pred)
print(c_m)
# Out:
# [[373 205]
#  [383 237]]

# %% [markdown]
# FOR LOGISTIC REGERESSION

# %%
lg=LogisticRegression()
lg.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %%
y_pred=lg.predict(X_test)
accuracy_lg=accuracy_score(Y_test,y_pred)

# %%
print(accuracy_lg)
# Out:
# 0.49081803005008345

# %%
cl_report =classification_report(Y_test,y_pred)
print(cl_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.48      0.65      0.55       578
#            1       0.51      0.34      0.41       620
#
#     accuracy                           0.49      1198
#    macro avg       0.50      0.50      0.48      1198
# weighted avg       0.50      0.49      0.48      1198

# %%
cml=confusion_matrix(Y_test,y_pred)
print(cml)
# Out:
# [[375 203]
#  [407 213]]

# %% [markdown]
# AFTER PCA

# %% [markdown]
# FOR KNN

# %%
from sklearn.decomposition import PCA

# Set n_components to a value less than or equal to min(n_samples, n_features)
# Since min(n_samples, n_features) is 6, we can set n_components to 6 or less.
pca = PCA(n_components=6)  # or any value between 1 and 6

X_train_pca = pca.fit_transform(X_train)
X_test_pca = pca.transform(X_test)

# %%
accuracy_list=[]
l=[]
for i in range(1,6):
  bkn=KNeighborsClassifier(n_neighbors=i)
  bkn.fit(X_train_pca,Y_train)
  accuracy_list.append([bkn.score(X_test_pca,Y_test)])
  l.append(i+1)

# %%
plt.plot(l,accuracy_list)

# %% [markdown]
# FOR SVM

# %%
svc=SVC()
svc.fit(X_train_pca,Y_train)
# Out:
# SVC()

# %%
y_pred=svc.predict(X_test_pca)
accuracy_svc=accuracy_score(Y_test,y_pred)

# %%
print(accuracy_svc)
# Out:
# 0.5183639398998331

# %%
c_report =classification_report(Y_test,y_pred)
print(c_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.50      0.52      0.51       578
#            1       0.54      0.52      0.53       620
#
#     accuracy                           0.52      1198
#    macro avg       0.52      0.52      0.52      1198
# weighted avg       0.52      0.52      0.52      1198

# %%
c_m=confusion_matrix(Y_test,y_pred)
print(c_m)
# Out:
# [[298 280]
#  [297 323]]

# %% [markdown]
# FOR LOGISTIC REGRESSION

# %%
lg=LogisticRegression()
lg.fit(X_train_pca,Y_train)
# Out:
# LogisticRegression()

# %%
y_pred=lg.predict(X_test_pca)
accuracy_lg=accuracy_score(Y_test,y_pred)

# %%
print(accuracy_lg)
# Out:
# 0.5292153589315526

# %%
cl_report =classification_report(Y_test,y_pred)
print(cl_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.51      0.52      0.52       578
#            1       0.55      0.53      0.54       620
#
#     accuracy                           0.53      1198
#    macro avg       0.53      0.53      0.53      1198
# weighted avg       0.53      0.53      0.53      1198

# %%
cml=confusion_matrix(Y_test,y_pred)
print(cml)
# Out:
# [[303 275]
#  [289 331]]

# %% [markdown]
# BOOTSRAP

# %%
svm=SVC()
knn=KNeighborsClassifier()
lr=LogisticRegression()

# %%
svm.fit(X_train,Y_train)
knn.fit(X_train,Y_train)
lr.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %%
svm_accuracy = accuracy_score(Y_test, svm.predict(X_test))
knn_accuracy = accuracy_score(Y_test, knn.predict(X_test))
log_reg_accuracy = accuracy_score(Y_test, lr.predict(X_test))

# %%
print("SVM Accuracy:", svm_accuracy)
print("KNN Accuracy:", knn_accuracy)
print("Logistic Regression Accuracy:", log_reg_accuracy)
# Out:
# SVM Accuracy: 0.5091819699499165
# KNN Accuracy: 0.508347245409015
# Logistic Regression Accuracy: 0.49081803005008345

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.utils import resample
import matplotlib.pyplot as plt
import seaborn as sns


def bootstrap_model(model, X_train, Y_train, X_test, Y_test, n_iterations=100):
    np.random.seed(42)
    scores = []

    for _ in range(n_iterations):
        X_resampled, y_resampled = resample(X_train, Y_train)
        model.fit(X_resampled, y_resampled)
        y_pred = model.predict(X_test)
        scores.append(accuracy_score(Y_test, y_pred))

    return scores


logreg = LogisticRegression(max_iter=1000, random_state=42)
svm = SVC(random_state=42)
knn = KNeighborsClassifier()

logreg_scores = bootstrap_model(logreg, X_train, Y_train, X_test, Y_test)
svm_scores = bootstrap_model(svm, X_train, Y_train, X_test, Y_test)
knn_scores = bootstrap_model(knn, X_train, Y_train, X_test, Y_test)

#FOR LOGISTIC REGERESSION
plt.figure(figsize=(10, 6))
sns.histplot(logreg_scores, kde=True, color='blue', label='Logistic Regression', bins=20)
plt.title('Bootstrap Accuracy Scores for Logistic regression')
plt.xlabel('Accuracy Score')
plt.ylabel('Frequency')
plt.legend()
plt.show()

#FOR SVM
plt.figure(figsize=(10, 6))
sns.histplot(svm_scores, kde=True, color='green', label='SVM', bins=20)
plt.title('Bootstrap Accuracy Scores for SVM')
plt.xlabel('Accuracy Score')
plt.ylabel('Frequency')
plt.legend()
plt.show()

#FOR KNN
plt.figure(figsize=(10, 6))
sns.histplot(knn_scores, kde=True, color='red', label='KNN', bins=20)
plt.title('Bootstrap Accuracy Scores for KNN')
plt.xlabel('Accuracy Score')
plt.ylabel('Frequency')
plt.legend()
plt.show()
